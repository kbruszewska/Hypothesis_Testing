# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Always state the H0 and H1 before conducting the hypothesis test.
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd 
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
# Your code here:
df = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
df.head()
# Out:
#                      Name                 Job Titles        Department  \
# 0  ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1       AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2       AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3         AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4         AGEE,  LAWRENCE             POLICE OFFICER            POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN        72510.0
# 1                 F           Salary            NaN        93354.0
# 2                 P           Hourly           20.0            NaN
# 3                 F           Salary            NaN       132972.0
# 4                 F           Salary            NaN        90024.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2         13.0
# 3          NaN
# 4          NaN

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
df.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25528
# Annual Salary         8174
# Hourly Rate          25528
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
display(df["Salary or Hourly"].unique())
df['Salary or Hourly'].value_counts()
# Out:
# array(['Salary', 'Hourly'], dtype=object)
# Salary or Hourly
# Salary    25528
# Hourly     8174
# Name: count, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:

# Method 1
df.groupby(['Department']).agg({'Name': 'count'}).reset_index()
# Out:
#              Department   Name
# 0          ADMIN HEARNG     38
# 1         ANIMAL CONTRL     75
# 2              AVIATION   1856
# 3     BOARD OF ELECTION    111
# 4       BOARD OF ETHICS      8
# 5         BUDGET & MGMT     44
# 6             BUILDINGS    258
# 7      BUSINESS AFFAIRS    167
# 8            CITY CLERK     88
# 9          CITY COUNCIL    362
# 10                 COPA    123
# 11     CULTURAL AFFAIRS     74
# 12                 DAIS   1033
# 13         DISABILITIES     28
# 14     FAMILY & SUPPORT    656
# 15              FINANCE    544
# 16                 FIRE   4627
# 17               HEALTH    467
# 18              HOUSING     66
# 19   HOUSING & ECON DEV    154
# 20      HUMAN RELATIONS     17
# 21      HUMAN RESOURCES     75
# 22        INSPECTOR GEN     95
# 23                  LAW    398
# 24    LICENSE APPL COMM      1
# 25       MAYOR'S OFFICE    104
# 26                 OEMC   1737
# 27               POLICE  13848
# 28         POLICE BOARD      2
# ...

# %%
# Method 2
df.pivot_table(index= ['Department'], values = ['Name'], aggfunc = 'count')
# Out:
#                       Name
# Department
# ADMIN HEARNG            38
# ANIMAL CONTRL           75
# AVIATION              1856
# BOARD OF ELECTION      111
# BOARD OF ETHICS          8
# BUDGET & MGMT           44
# BUILDINGS              258
# BUSINESS AFFAIRS       167
# CITY CLERK              88
# CITY COUNCIL           362
# COPA                   123
# CULTURAL AFFAIRS        74
# DAIS                  1033
# DISABILITIES            28
# FAMILY & SUPPORT       656
# FINANCE                544
# FIRE                  4627
# HEALTH                 467
# HOUSING                 66
# HOUSING & ECON DEV     154
# HUMAN RELATIONS         17
# HUMAN RESOURCES         75
# INSPECTOR GEN           95
# LAW                    398
# LICENSE APPL COMM        1
# MAYOR'S OFFICE         104
# OEMC                  1737
# POLICE               13848
# POLICE BOARD             2
# PROCUREMENT             84
# PUBLIC LIBRARY        1088
# PUBLIC SAFETY ADMIN    244
# STREETS & SAN         2175
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:

#(KB) we consider the data we have as a sample (not the whole population)
# We write what is hypothesis and anti hypo and what significance level we take, then execute the test and then conclusion
# if we should accept/reject the hypothesis.

# %% [markdown]
# 1. I select a value for alpha of 0.05 (p-value threshold, significance level)
# -(because we want to have 95% two sided confidence interval)
#
# 2. Two-sided test:
# - Null hypothesis or H0: mean hourly wage value = 30
# - Alternative hyp or H1: mean hourly wage value <> 30

# %%
import scipy.stats
from scipy.stats import ttest_1samp

# %%
hourly = df.dropna(subset=['Hourly Rate'])

# %%
hourly
# Out:
#                          Name                      Job Titles  \
# 2           AFOENYI,  PHYLLIS       TITLE V PROGRAM TRAINEE I
# 5           AGNEW,  ANTONIO E              MOTOR TRUCK DRIVER
# 15         AGSALUD,  FERNAN S              SANITATION LABORER
# 16     AGSALUD JR,  JUANITO S              SANITATION LABORER
# 21            AGUAYO,  LUIS M            LABORER - APPRENTICE
# ...                       ...                             ...
# 33676         ZUNIGA,  THOMAS           GENERAL LABORER - DSS
# 33678             ZUNO,  ERIK            CONSTRUCTION LABORER
# 33681      ZURAWSKI,  JEFFREY  FRM OF MACHINISTS - AUTOMOTIVE
# 33684         ZUREK,  FRANCIS             ELECTRICAL MECHANIC
# 33688      ZWARYCZ,  THOMAS J              MOTOR TRUCK DRIVER
#
#                 Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 2         FAMILY & SUPPORT                 P           Hourly           20.0
# ...

# %%
# hourly = df["Hourly Rate"].dropna

# %%
hourly.head()
# Out:
#                       Name                 Job Titles        Department  \
# 2        AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 5        AGNEW,  ANTONIO E         MOTOR TRUCK DRIVER          AVIATION
# 15      AGSALUD,  FERNAN S         SANITATION LABORER     STREETS & SAN
# 16  AGSALUD JR,  JUANITO S         SANITATION LABORER     STREETS & SAN
# 21         AGUAYO,  LUIS M       LABORER - APPRENTICE       WATER MGMNT
#
#    Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 2                  P           Hourly           20.0            NaN
# 5                  F           Hourly           40.0            NaN
# 15                 F           Hourly           40.0            NaN
# 16                 F           Hourly           40.0            NaN
# 21                 F           Hourly           40.0            NaN
#
#     Hourly Rate
# 2         13.00
# 5         37.45
# 15        40.78
# 16        38.52
# 21        34.98

# %%
# hourly.mean()

# %%
# Parameters for confidence_interval:
confidence_level = 0.95


degrees_freedom = (len(hourly) - 1)
sample_mean = np.mean(hourly["Hourly Rate"])
sample_standard_error = scipy.stats.sem(hourly["Hourly Rate"]) 


confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865) .

# %%
stat, pval = ttest_1samp(hourly["Hourly Rate"], 30)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   31.211500329216044
# pvalue for the two-tailed test is  3.825475847673794e-202

# %% [markdown]
# ### Interpretation:
#
# - Here we have two-tailed-test, so we need only to look on pvalue, and stat is not important.
# - pvalue is much smaller than for alpha of 0.05
#         This means that our null hypothesis or H0: mean hourly wage value = 30 is not true, and we need to reject the H0.

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our Null hypothesis is less than or equal to, then to reject, the test statistic must be positive (rejects the <) and the p-value below 0.05 (rejects the =).

# %%
# Your code here:
salary = df.dropna(subset=['Annual Salary'])

# %%
salary
# Out:
#                          Name               Job Titles   Department  \
# 0      ADRIANO,  RACQUEL ANNE                PARAMEDIC         FIRE
# 1           AFFANEH,  MAHIR A           POLICE OFFICER       POLICE
# 3             AGAR,  BULENT B      DEPUTY COMMISSIONER  WATER MGMNT
# 4             AGEE,  LAWRENCE           POLICE OFFICER       POLICE
# 6           AGNEW,  MELISSA M                 SERGEANT       POLICE
# ...                       ...                      ...          ...
# 33697      ZYLINSKA,  KLAUDIA           POLICE OFFICER       POLICE
# 33698      ZYMANTAS,  LAURA C           POLICE OFFICER       POLICE
# 33699       ZYMANTAS,  MARK E           POLICE OFFICER       POLICE
# 33700     ZYRKOWSKI,  CARLO E           POLICE OFFICER       POLICE
# 33701     ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST         DAIS
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                     F           Salary            NaN        72510.0
# ...

# %%
salary_department = salary.pivot_table(index= ['Department'], values = ['Annual Salary'], aggfunc = np.mean)

# %%
salary_department
# Out:
#                      Annual Salary
# Department
# ADMIN HEARNG          80429.368421
# ANIMAL CONTRL         71333.904762
# AVIATION              78736.342056
# BOARD OF ELECTION     53915.315676
# BOARD OF ETHICS       99795.000000
# BUDGET & MGMT         98641.428571
# BUILDINGS            106854.316744
# BUSINESS AFFAIRS      84961.575000
# CITY CLERK            74520.351818
# CITY COUNCIL          71314.166667
# COPA                  82272.682927
# CULTURAL AFFAIRS      88910.625000
# DAIS                  94257.264167
# DISABILITIES          88932.444444
# FAMILY & SUPPORT      84472.394649
# FINANCE               76588.304609
# FIRE                  96514.640813
# HEALTH                90871.380645
# HOUSING               92063.909091
# HOUSING & ECON DEV    89883.655629
# HUMAN RELATIONS       94992.000000
# HUMAN RESOURCES       85977.440000
# INSPECTOR GEN         85603.578947
# LAW                   93691.645714
# LICENSE APPL COMM     93984.000000
# ...

# %%
police_force = salary.loc[salary['Department'] == 'POLICE']
police_force
# Out:
#                        Name                              Job Titles  \
# 1         AFFANEH,  MAHIR A                          POLICE OFFICER
# 4           AGEE,  LAWRENCE                          POLICE OFFICER
# 6         AGNEW,  MELISSA M                                SERGEANT
# 7         AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 1         POLICE                 F           Salary            NaN
# ...

# %% [markdown]
# 1. I select a value for alpha of 0.05 (p-value threshold, significance level)
# -(because we want to have 95% two sided confidence interval)
#
# 2. One-sided test:
# - Null hypothesis or H0: mean annual salary >= 86000
# - Alternative hyp or H1: mean annual salary < 86000

# %%
# Parameters for confidence_interval:
confidence_level = 0.95


degrees_freedom = (len(police_force) - 1)
sample_mean = np.mean(police_force["Annual Salary"])
sample_standard_error = scipy.stats.sem(police_force["Annual Salary"]) 


confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (88534.1182885883, 89134.11955863392) .

# %%
stat, pval = ttest_1samp(police_force["Annual Salary"], 86000)

# %%
print('stat is  ', stat)
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   18.51748561981861
# pvalue for the one-tailed test is  6.119566952121482e-76

# %%
# Interpretation
# pvalue is very small, so we could reject the equality from out null hypothesis. However we still need to check stat as well,
# because we have ">" sign in our comparition.
# stat is positive in the same direction as our null hypothesis, so it means stat is in a good direction
# and we cannot reject the null hypothesis. 
# This means, that our null hypothesis was true and that average salary in police is >= 86000 per year.

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:
cross_tab = pd.crosstab(df['Department'],df['Salary or Hourly'])
cross_tab
# Out:
# Salary or Hourly     Hourly  Salary
# Department
# ADMIN HEARNG              0      38
# ANIMAL CONTRL            12      63
# AVIATION               1214     642
# BOARD OF ELECTION         0     111
# BOARD OF ETHICS           0       8
# BUDGET & MGMT             2      42
# BUILDINGS                 0     258
# BUSINESS AFFAIRS          7     160
# CITY CLERK                0      88
# CITY COUNCIL             74     288
# COPA                      0     123
# CULTURAL AFFAIRS         10      64
# DAIS                    745     288
# DISABILITIES              1      27
# FAMILY & SUPPORT        357     299
# FINANCE                  45     499
# FIRE                      0    4627
# HEALTH                    2     465
# HOUSING                   0      66
# HOUSING & ECON DEV        3     151
# HUMAN RELATIONS           0      17
# HUMAN RESOURCES           0      75
# INSPECTOR GEN             0      95
# LAW                      48     350
# ...

# %%
# Observation:
# the department that has the most hourly workers is STREETS & SAN.

# %%
max_index_hourly = cross_tab['Hourly'].idxmax()
max_index_hourly
# Out:
# 'STREETS & SAN'

# %%
row_with_max_value = cross_tab.loc['STREETS & SAN']
row_with_max_value
# Out:
# Salary or Hourly
# Hourly    1846
# Salary     329
# Name: STREETS & SAN, dtype: int64

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:

# %% [markdown]
# 1. I select a value for alpha of 0.05 (p-value threshold, significance level)
# -(because we want to have 95% two sided confidence interval)
#
# 2. One-sided test:
# - Null hypothesis or H0: mean hourly wage in department 'STREETS & SAN' <= 35
# - Alternative hyp or H1: mean hourly wage in department 'STREETS & SAN' > 35

# %%
dep_streets_san = hourly.loc[hourly['Department'] == 'STREETS & SAN']  #All rows and chosen columns
dep_streets_san
# Out:
#                          Name               Job Titles     Department  \
# 15         AGSALUD,  FERNAN S       SANITATION LABORER  STREETS & SAN
# 16     AGSALUD JR,  JUANITO S       SANITATION LABORER  STREETS & SAN
# 26           AGUILAR,  EFRAIN       SANITATION LABORER  STREETS & SAN
# 49     ABDUL-SHAKUR,  TAHIR J  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 65          ABRAMS,  SAMUEL A  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# ...                       ...                      ...            ...
# 33623        ZIZUMBO,  JOSE N       MOTOR TRUCK DRIVER  STREETS & SAN
# 33624          ZIZUMBO,  LUIS       MOTOR TRUCK DRIVER  STREETS & SAN
# 33667        ZUMMO,  ROBERT J       MOTOR TRUCK DRIVER  STREETS & SAN
# 33668     ZUNICH,  JONATHAN G       SANITATION LABORER  STREETS & SAN
# 33676         ZUNIGA,  THOMAS    GENERAL LABORER - DSS  STREETS & SAN
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# ...

# %%
# Parameters for confidence_interval:
confidence_level = 0.95

degrees_freedom = (len(dep_streets_san) - 1)
sample_mean = np.mean(dep_streets_san["Hourly Rate"])
sample_standard_error = scipy.stats.sem(dep_streets_san["Hourly Rate"]) 


confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (35.28150811892106, 35.82308559722194) .

# %%
stat, pval = ttest_1samp(police_force["Annual Salary"], 86000)

# %%
print('stat is  ', stat)
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   18.51748561981861
# pvalue for the one-tailed test is  6.119566952121482e-76

# %%
# Interpretation
# pvalue is very small, so we could reject the equality from our null hypothesis. 
# However we still need to check stat as well, because we have ">" sign in our comparition.
# stat is positive in the other direction as our null hypothesis, so it means stat is in a wrong direction
# and we can reject the null hypothesis. 

# This means, that our null hypothesis was not true and that mean hourly wage in department 'STREETS & SAN' is higher than 35$.(>35)

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:

# %%
hourly.head()
# Out:
#                       Name                 Job Titles        Department  \
# 2        AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 5        AGNEW,  ANTONIO E         MOTOR TRUCK DRIVER          AVIATION
# 15      AGSALUD,  FERNAN S         SANITATION LABORER     STREETS & SAN
# 16  AGSALUD JR,  JUANITO S         SANITATION LABORER     STREETS & SAN
# 21         AGUAYO,  LUIS M       LABORER - APPRENTICE       WATER MGMNT
#
#    Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 2                  P           Hourly           20.0            NaN
# 5                  F           Hourly           40.0            NaN
# 15                 F           Hourly           40.0            NaN
# 16                 F           Hourly           40.0            NaN
# 21                 F           Hourly           40.0            NaN
#
#     Hourly Rate
# 2         13.00
# 5         37.45
# 15        40.78
# 16        38.52
# 21        34.98

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Parameters for confidence_interval:
confidence_level = 0.95

degrees_freedom = (len(hourly) - 1)
sample_mean = np.mean(hourly["Hourly Rate"])
sample_standard_error = scipy.stats.sem(hourly["Hourly Rate"]) 


confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865) .

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
